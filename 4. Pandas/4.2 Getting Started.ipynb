# %% [markdown]
# #### Topics to be covered
#
# * **Series -** a single column (can be multiple rows) of values.
# * **DataFrame -** multiple columns/rows of values (a DataFrame is comprised of multiple Series).
# * **Importing data -** we used pd.read_csv() to read in a CSV (comma-separated values) file but there are multiple options for reading data.
# * **Exporting data -** we exported our data using to_csv(), however there are multiple methods of exporting data.
#    - **Describing data**
#    * `df.dtypes` - find the datatypes present in a dataframe.
#    * `df.describe()` - find various numerical features of a dataframe.
#    * `df.info()` - find the number of rows and whether or not any of them are empty.
#    - **Viewing and selecting data**
#    * `df.head()` - view the first 5 rows of df.
#    * `df.loc & df.iloc` - select specific parts of a dataframe.
#    * `df['A']` - select column A of df.
#    * `df[df['A'] > 1000]` - selection column A rows with values over 1000 of df.
#    * `df['A']` - plot values from column A using matplotlib (defaults to line graph).
# * **Manipulating data and performing operations -** pandas has many built-in functions you can use to manipulate data, also many of the Python operators (e.g. +, -, >, ==) work with pandas.

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # [10 Minutes to panda](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)

# %% [markdown]
# ##### Types of Datatypes
#
# - Series - a 1-dimensional column of data.
# - DataFrame (most common) - a 2-dimesional table of data with rows and columns.

# %%
# series datatypes
cars = pd.Series(['BMW','Toyota','Honda'])
cars
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors = pd.Series(['Red','Green','Blue'])
colors
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# creating series with index and name of series as Product A
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
# DataFrame datatypes
car_data = pd.DataFrame({'cars': cars, 'colors':colors})
car_data
# Out:
#      cars colors
# 0     BMW    Red
# 1  Toyota  Green
# 2   Honda   Blue

# %%
# Gives error Series cannot be used directly
# car_data = pd.DataFrame({cars,colors})
# car_data

# %% [markdown]
# <p style="color:red"> Error : 'utf-8' codec can't decode byte 0xf4 in position 5055: invalid continuation byte</p>
# <p style="color:blue">  Reason : Your data set may have data in multiple encoding format.</p>
# <p style="color:green"> Solution : Add encoding='latin1'. latin1 can decode almost every type of byte sequence. There are more encodings available you may use.</p>

# %%
# importing data
petrol_dataset = pd.read_csv('../datasets/petrol_dataset_june_2022.csv',encoding='latin1')
petrol_dataset
# Out:
#        #                  Country  Daily Oil Consumption (Barrels)  \
# 0      1            United States                         19687287
# 1      2                    China                         12791553
# 2      3                    India                          4443000
# 3      4                    Japan                          4012877
# 4      5                   Russia                          3631287
# ..   ...                      ...                              ...
# 176  177  Saint Pierre & Miquelon                              660
# 177  178                 Kiribati                              400
# 178  179               Montserrat                              400
# 179  180             Saint Helena                               70
# 180  181                     Niue                               51
#
#     World Share  Yearly Gallons Per Capita  Price Per Gallon (USD)  \
# 0        20.30%                      934.3                    5.19
# ...

# %%
# Exporting a dataframe
petrol_dataset.to_csv('exported_petrol_dataset.csv',index=False)

# %%
exported_csv = pd.read_csv('exported_petrol_dataset.csv')
exported_csv
# Out:
#        #                  Country  Daily Oil Consumption (Barrels)  \
# 0      1            United States                         19687287
# 1      2                    China                         12791553
# 2      3                    India                          4443000
# 3      4                    Japan                          4012877
# 4      5                   Russia                          3631287
# ..   ...                      ...                              ...
# 176  177  Saint Pierre & Miquelon                              660
# 177  178                 Kiribati                              400
# 178  179               Montserrat                              400
# 179  180             Saint Helena                               70
# 180  181                     Niue                               51
#
#     World Share  Yearly Gallons Per Capita  Price Per Gallon (USD)  \
# 0        20.30%                      934.3                    5.19
# ...

# %% [markdown]
# # Describing Data

# %%
# Attribute
petrol_dataset.dtypes
# Out:
# #                                    int64
# Country                             object
# Daily Oil Consumption (Barrels)      int64
# World Share                         object
# Yearly Gallons Per Capita          float64
# Price Per Gallon (USD)             float64
# Price Per Liter (USD)              float64
# Price Per Liter (PKR)              float64
# dtype: object

# %%
petrol_dataset.columns
# Returns columns of dataset as list
# Out:
# Index(['#', 'Country', 'Daily Oil Consumption (Barrels)', 'World Share',
#        'Yearly Gallons Per Capita', 'Price Per Gallon (USD)',
#        'Price Per Liter (USD)', 'Price Per Liter (PKR)'],
#       dtype='object')

# %%
petrol_dataset.index
# Returns start index of row (start) , total rows i.e. stop index (stop) and number of steps (steps)
# Out:
# RangeIndex(start=0, stop=181, step=1)

# %%
# They both are different functions
petrol_dataset.describe()
# petrol_dataset.describe
# Out:
#                 #  Daily Oil Consumption (Barrels)  Yearly Gallons Per Capita  \
# count  181.000000                     1.810000e+02                 181.000000
# mean    91.000000                     5.335730e+05                 332.006630
# std     52.394338                     1.858067e+06                 436.558735
# min      1.000000                     5.100000e+01                   2.200000
# 25%     46.000000                     2.003600e+04                  53.900000
# 50%     91.000000                     6.161200e+04                 180.200000
# 75%    136.000000                     2.623520e+05                 424.600000
# max    181.000000                     1.968729e+07                3679.500000
#
#        Price Per Gallon (USD)  Price Per Liter (USD)  Price Per Liter (PKR)
# count              181.000000             181.000000             181.000000
# mean                 5.695691               1.505138             318.219227
# ...

# %%
# Getting info about columns
petrol_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   #                                181 non-null    int64
#  1   Country                          181 non-null    object
#  2   Daily Oil Consumption (Barrels)  181 non-null    int64
#  3   World Share                      181 non-null    object
#  4   Yearly Gallons Per Capita        181 non-null    float64
#  5   Price Per Gallon (USD)           181 non-null    float64
#  6   Price Per Liter (USD)            181 non-null    float64
#  7   Price Per Liter (PKR)            181 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 11.4+ KB

# %%
# list of unique values and how often they occur in the dataset, we can use the value_counts() method
petrol_dataset.value_counts()
# Out:
# #    Country                 Daily Oil Consumption (Barrels)  World Share  Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  Price Per Liter (PKR)
# 1    United States           19687287                         20.30%       934.3                      5.19                    1.37                   289.97                   1
# 115  Benin                   36000                            0.04%        50.8                       3.63                    0.96                   202.83                   1
# 117  Bosnia and Herzegovina  35000                            0.04%        158.4                      6.55                    1.73                   366.11                   1
# 118  Georgia                 33000                            0.03%        126.0                      5.04                    1.33                   281.51                   1
# ...

# %%
# Getting the mean of possible columns
petrol_dataset.mean()
# Out:
# C:\Users\shyam\AppData\Local\Temp/ipykernel_18680/2931909330.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   petrol_dataset.mean()
# #                                      91.000000
# Daily Oil Consumption (Barrels)    533573.049724
# Yearly Gallons Per Capita             332.006630
# Price Per Gallon (USD)                  5.695691
# Price Per Liter (USD)                   1.505138
# Price Per Liter (PKR)                 318.219227
# dtype: float64

# %%
# Defining our data-series and getting the mean
petrol_dataset = pd.Series([3,4,5])
petrol_dataset.mean()
# Out:
# 4.0

# %%
petrol_dataset = pd.read_csv('./../datasets/petrol_dataset_june_2022.csv',encoding='latin1')

# Directly using the function gives error
petrol_dataset.sum

# So passing column which we need to find sum of
petrol_dataset['Price Per Gallon (USD)'].sum()
# Out:
# 1030.92

# %%
# Getting length of data set
len(petrol_dataset)
# Out:
# 181

# %% [markdown]
# # Viewing and Selecting data

# %%
# Returning top 5 rows of data set
petrol_dataset.head()
# Out:
#    #        Country  Daily Oil Consumption (Barrels) World Share  \
# 0  1  United States                         19687287      20.30%
# 1  2          China                         12791553      13.20%
# 2  3          India                          4443000       4.60%
# 3  4          Japan                          4012877       4.10%
# 4  5         Russia                          3631287       3.70%
#
#    Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                      934.3                    5.19                   1.37
# 1                      138.7                    5.42                   1.43
# 2                       51.4                    5.05                   1.33
# 3                      481.5                    4.69                   1.24
# 4                      383.2                    3.41                   0.90
#
#    Price Per Liter (PKR)
# 0                 289.97
# 1                 302.87
# 2                 281.93
# ...

# %%
# Getting custom number of rows
petrol_dataset.head(7)
# Out:
#    #        Country  Daily Oil Consumption (Barrels) World Share  \
# 0  1  United States                         19687287      20.30%
# 1  2          China                         12791553      13.20%
# 2  3          India                          4443000       4.60%
# 3  4          Japan                          4012877       4.10%
# 4  5         Russia                          3631287       3.70%
# 5  6   Saudi Arabia                          3302000       3.40%
# 6  7         Brazil                          2984000       3.10%
#
#    Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                      934.3                    5.19                   1.37
# 1                      138.7                    5.42                   1.43
# 2                       51.4                    5.05                   1.33
# 3                      481.5                    4.69                   1.24
# ...

# %%
# Getting bottom 5 rows
petrol_dataset.tail()
# Out:
#        #                  Country  Daily Oil Consumption (Barrels)  \
# 176  177  Saint Pierre & Miquelon                              660
# 177  178                 Kiribati                              400
# 178  179               Montserrat                              400
# 179  180             Saint Helena                               70
# 180  181                     Niue                               51
#
#     World Share  Yearly Gallons Per Capita  Price Per Gallon (USD)  \
# 176       0.00%                     1705.1                    8.27
# 177       0.00%                       54.5                    4.09
# 178       0.00%                     1231.1                    4.57
# 179       0.00%                      180.2                    5.53
# 180       0.00%                      484.4                   11.43
#
#      Price Per Liter (USD)  Price Per Liter (PKR)
# 176                   2.19                 462.13
# 177                   1.08                 228.42
# ...

# %%
# .loc and .iloc
animals = pd.Series(['cat','dog','snake','bear','tiger'])
print(animals)

animals = pd.Series(['cat','dog','snake','bear','tiger'],index=[0,3,6,4,2])
animals
# Out:
# 0      cat
# 1      dog
# 2    snake
# 3     bear
# 4    tiger
# dtype: object
# 0      cat
# 3      dog
# 6    snake
# 4     bear
# 2    tiger
# dtype: object

# %%
animals.loc[3]
# Out:
# 'dog'

# %%
# .loc[] refers to index
petrol_dataset.loc[3]
# Out:
# #                                        4
# Country                              Japan
# Daily Oil Consumption (Barrels)    4012877
# World Share                          4.10%
# Yearly Gallons Per Capita            481.5
# Price Per Gallon (USD)                4.69
# Price Per Liter (USD)                 1.24
# Price Per Liter (PKR)               262.05
# Name: 3, dtype: object

# %%
# .iloc refers to position
petrol_dataset.iloc[4]
# Out:
# #                                        5
# Country                             Russia
# Daily Oil Consumption (Barrels)    3631287
# World Share                          3.70%
# Yearly Gallons Per Capita            383.2
# Price Per Gallon (USD)                3.41
# Price Per Liter (USD)                  0.9
# Price Per Liter (PKR)               190.56
# Name: 4, dtype: object

# %%
petrol_dataset.iloc[:3]
# Out:
#    #        Country  Daily Oil Consumption (Barrels) World Share  \
# 0  1  United States                         19687287      20.30%
# 1  2          China                         12791553      13.20%
# 2  3          India                          4443000       4.60%
#
#    Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                      934.3                    5.19                   1.37
# 1                      138.7                    5.42                   1.43
# 2                       51.4                    5.05                   1.33
#
#    Price Per Liter (PKR)
# 0                 289.97
# 1                 302.87
# 2                 281.93

# %%
# Accessing a column
petrol_dataset.Country
petrol_dataset['Country']
# Out:
# 0                United States
# 1                        China
# 2                        India
# 3                        Japan
# 4                       Russia
#                 ...
# 176    Saint Pierre & Miquelon
# 177                   Kiribati
# 178                 Montserrat
# 179               Saint Helena
# 180                       Niue
# Name: Country, Length: 181, dtype: object

# %%
# Getting data in range
petrol_dataset[petrol_dataset['Price Per Liter (PKR)']>=800]
# Out:
#        #      Country  Daily Oil Consumption (Barrels) World Share  \
# 139  140  North Korea                            18000       0.02%
# 175  176        Tonga                              899       0.00%
#
#      Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 139                       10.9                   54.89                  14.50
# 175                      136.3                   16.20                   4.28
#
#      Price Per Liter (PKR)
# 139                3066.75
# 175                 905.22

# %%
# petrol_dataset[petrol_dataset['Price Per Liter (PKR)']>=800 & petrol_dataset['Price Per Liter (PKR)']<=1200]
petrol_dataset[(petrol_dataset['Price Per Liter (PKR)']>=800) & (petrol_dataset['Price Per Liter (PKR)']<=900)]
# Out:
# Empty DataFrame
# Columns: [#, Country, Daily Oil Consumption (Barrels), World Share, Yearly Gallons Per Capita, Price Per Gallon (USD), Price Per Liter (USD), Price Per Liter (PKR)]
# Index: []

# %% [markdown]
# <p style="color:red"> Error : Above code gives error "Series are ambiguous cannot have boolean value" </p>
# <p style="color:blue">  Reason : We have not used proper brackets</p>
# <p style="color:green"> Solution : Use proper brackets</p>

# %%
pd.crosstab(petrol_dataset['Price Per Gallon (USD)'] , petrol_dataset['Price Per Liter (PKR)'])
# Out:
# Price Per Liter (PKR)   4.65     6.56     11.21    46.53    60.49    66.20    \
# Price Per Gallon (USD)
# 0.08                          1        0        0        0        0        0
# 0.12                          0        1        0        0        0        0
# 0.20                          0        0        1        0        0        0
# 0.83                          0        0        0        1        0        0
# 1.08                          0        0        0        0        1        0
# ...                         ...      ...      ...      ...      ...      ...
# 10.22                         0        0        0        0        0        0
# 11.35                         0        0        0        0        0        0
# 11.43                         0        0        0        0        0        0
# 16.20                         0        0        0        0        0        0
# 54.89                         0        0        0        0        0        0
#
# ...

# %%
# Grouping
petrol_dataset.groupby(['Price Per Liter (PKR)']).mean()

# Grouping multiple rows
petrol_dataset.groupby(['Price Per Liter (PKR)','Price Per Gallon (USD)']).mean()
# Out:
#                                                   #  \
# Price Per Liter (PKR) Price Per Gallon (USD)
# 4.65                  0.08                     33.0
# 6.56                  0.12                     61.0
# 11.21                 0.20                     12.0
# 46.53                 0.83                    147.0
# 60.49                 1.08                     74.0
# ...                                             ...
# 571.26                10.22                    65.0
# 634.29                11.35                    40.0
# 638.73                11.43                   181.0
# 905.22                16.20                   176.0
# 3066.75               54.89                   140.0
#
#                                               Daily Oil Consumption (Barrels)  \
# Price Per Liter (PKR) Price Per Gallon (USD)
# 4.65                  0.08                                           598000.0
# 6.56                  0.12                                           223000.0
# ...

# %%
# The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.

# apply() is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.

petrol_dataset['Price Per Gallon (USD)'].map(lambda p : p - petrol_dataset['Price Per Gallon (USD)'].mean())

def func(row):
   row['Price Per Gallon (USD)'] -= row['Price Per Gallon (USD)']
   return row
petrol_dataset.apply(func,axis='columns')
# Out:
#        #                  Country  Daily Oil Consumption (Barrels)  \
# 0      1            United States                         19687287
# 1      2                    China                         12791553
# 2      3                    India                          4443000
# 3      4                    Japan                          4012877
# 4      5                   Russia                          3631287
# ..   ...                      ...                              ...
# 176  177  Saint Pierre & Miquelon                              660
# 177  178                 Kiribati                              400
# 178  179               Montserrat                              400
# 179  180             Saint Helena                               70
# 180  181                     Niue                               51
#
#     World Share  Yearly Gallons Per Capita  Price Per Gallon (USD)  \
# 0        20.30%                      934.3                     0.0
# ...

# %% [markdown]
# # Sorting Data

# %%
petrol_dataset.sort_values(by='Price Per Gallon (USD)')
# Out:
#        #      Country  Daily Oil Consumption (Barrels) World Share  \
# 32    33    Venezuela                           598000       0.60%
# 60    61        Libya                           223000       0.20%
# 11    12         Iran                          1803999       1.90%
# 146  147      Brunei                             16000       0.02%
# 73    74        Syria                           140000       0.10%
# ..   ...          ...                              ...         ...
# 64    65       Norway                           204090       0.20%
# 39    40    Hong Kong                           408491       0.40%
# 180  181         Niue                               51       0.00%
# 175  176        Tonga                              899       0.00%
# 139  140  North Korea                            18000       0.02%
#
#      Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 32                       307.1                    0.08                   0.02
# ...

# %%
petrol_dataset.reset_index()
# Out:
#      index    #                  Country  Daily Oil Consumption (Barrels)  \
# 0        0    1            United States                         19687287
# 1        1    2                    China                         12791553
# 2        2    3                    India                          4443000
# 3        3    4                    Japan                          4012877
# 4        4    5                   Russia                          3631287
# ..     ...  ...                      ...                              ...
# 176    176  177  Saint Pierre & Miquelon                              660
# 177    177  178                 Kiribati                              400
# 178    178  179               Montserrat                              400
# 179    179  180             Saint Helena                               70
# 180    180  181                     Niue                               51
#
#     World Share  Yearly Gallons Per Capita  Price Per Gallon (USD)  \
# ...

# %%
petrol_dataset.sort_values(by=['Country','World Share'],ascending=False)
# Out:
#        #      Country  Daily Oil Consumption (Barrels) World Share  \
# 123  124     Zimbabwe                            24000       0.03%
# 128  129       Zambia                            22000       0.02%
# 91    92        Yemen                            60000       0.06%
# 33    34      Vietnam                           478000       0.50%
# 32    33    Venezuela                           598000       0.60%
# ..   ...          ...                              ...         ...
# 27    28    Argentina                           709000       0.70%
# 71    72       Angola                           133000       0.10%
# 37    38      Algeria                           429000       0.40%
# 121  122      Albania                            27000       0.03%
# 115  116  Afghanistan                            35000       0.04%
#
#      Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 123                       26.2                    6.13                   1.62
# ...

# %%
# Another groupby() method worth mentioning is agg(), which lets you run a bunch of different functions on your 
# DataFrame simultaneously. 

petrol_dataset.groupby('Country')['Price Per Gallon (USD)'].agg([min,max])
# Out:
#               min   max
# Country
# Afghanistan  3.62  3.62
# Albania      8.00  8.00
# Algeria      1.18  1.18
# Angola       1.39  1.39
# Argentina    3.96  3.96
# ...           ...   ...
# Venezuela    0.08  0.08
# Vietnam      5.38  5.38
# Yemen        1.96  1.96
# Zambia       5.59  5.59
# Zimbabwe     6.13  6.13
#
# [181 rows x 2 columns]

# %%
petrol_dataset['Price Per Gallon (USD)'].plot()
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
petrol_dataset.plot()
# Out:
# <AxesSubplot:>

# %%
petrol_dataset['Yearly Gallons Per Capita'].plot()
petrol_dataset['Price Per Gallon (USD)'].plot()
petrol_dataset['Price Per Liter (PKR)'].plot()
petrol_dataset['Price Per Liter (USD)'].plot()
# Out:
# <AxesSubplot:>

# %%
# Creating histogram
petrol_dataset['Daily Oil Consumption (Barrels)'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating Data

# %%
#
petrol_dataset['Country'].str.lower()
# Out:
# 0                united states
# 1                        china
# 2                        india
# 3                        japan
# 4                       russia
#                 ...
# 176    saint pierre & miquelon
# 177                   kiribati
# 178                 montserrat
# 179               saint helena
# 180                       niue
# Name: Country, Length: 181, dtype: object

# %%
petrol_dataset['Country'] = petrol_dataset['Country'].str.capitalize()

# %%
cities = pd.Series(['Gwalior','','Morena','Mumbai','','Delhi'])
cities
# Out:
# 0    Gwalior
# 1
# 2     Morena
# 3     Mumbai
# 4
# 5      Delhi
# dtype: object

# %% [markdown]
# ##### Entries missing values are given the value NaN, short for "Not a Number". For technical reasons these NaN values are always of the float64 dtype.

# %%
# Filling missing places with NaN
# .fillna()

# %%
# Column from Series
seats = pd.Series([3,5,2,6,3])
car_data['seats'] = seats
car_data
# Out:
#      cars colors  seats
# 0     BMW    Red      3
# 1  Toyota  Green      5
# 2   Honda   Blue      2

# %%
# Column from list
avg = [3.4, 6.3, 2.6]
car_data['Average'] = avg
car_data
# Out:
#      cars colors  seats  Average
# 0     BMW    Red      3      3.4
# 1  Toyota  Green      5      6.3
# 2   Honda   Blue      2      2.6

# %%
petrol_dataset.sample(frac=0.01)
# Out:
#        #             Country  Daily Oil Consumption (Barrels) World Share  \
# 21    22              Taiwan                           981203       1.00%
# 124  125  State of palestine                            24001       0.03%
#
#      Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 21                       636.9                    3.94                   1.04
# 124                       79.4                    6.62                   1.75
#
#      Price Per Liter (PKR)
# 21                  220.17
# 124                 370.13
