# %% [markdown]
# # Solution

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours
colors = pd.Series(['Red','Green','Blue'])

# %%
# View the series of different colours
colors
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# Create a series of three different car types and view it
car_types = pd.Series(['BMW','Jaguar','Verna'])
car_types
# Out:
# 0       BMW
# 1    Jaguar
# 2     Verna
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
cars = pd.DataFrame({'Car Types':car_types, 'Car Colour':colors})
cars
# Out:
#   Car Types Car Colour
# 0       BMW        Red
# 1    Jaguar      Green
# 2     Verna       Blue

# %%
# Import "../datasets/car-sales.csv" and turn it into a DataFrame
car_sales = pd.read_csv('../datasets/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# **Note:** Since you've imported `../datasets/car-sales.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
car_sales.to_csv('exported_car_sales.csv')

# %%
# Find the different datatypes of the car data DataFrame
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# What does it show you?<br>
# Answer :
# - Make                object
# - Colour              object
# - Odometer (KM)       int64
# - Doors               int64
# - Price               object
# <br>dtypes: int64(2), object(3)

# %%
# Create a Series of different numbers and find the mean of them
mean_numbers = pd.Series([6,3,6,2,6,3,7])
mean_numbers.mean()
# Out:
# 4.714285714285714

# %%
# Create a Series of different numbers and find the sum of them
sum_numbers = pd.Series([6,3,6,2,6,3,7])
sum_numbers.sum()
# Out:
# 33

# %%
# List out all the column names of the car sales DataFrame
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
len(car_sales)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
car_sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
car_sales[car_sales['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
car_sales.groupby(car_sales['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as mpt

# %%
# Create a histogram of the Odometer column using hist()
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
# Try to plot the Price column using plot()
# car_sales['Price'].plot()
# TypeError: no numeric data to plot

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Remove the punctuation from price column
car_sales['Price'] = car_sales['Price'].replace('[\$\,]', '', regex=True).astype(float)

# %%
# Check the changes to the price column
car_sales['Price']
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price, dtype: float64

# %%
car_sales['Price'] = car_sales['Price'].replace('[\$\,\.]', '', regex=True).astype(int)

# %%
# Check the changes to the price column
car_sales['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
# Lower the strings of the Make column
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
# Make lowering the case of the Make column permanent
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
# Check the car sales DataFrame
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
missing_car_sales = pd.read_csv('../datasets/car-sales-missing.csv')
# Check out the new DataFrame
missing_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White            NaN    4.0   $4,000.00
# 1     NaN    Red        87899.0    4.0         NaN
# 2  Toyota   Blue        32549.0    3.0   $7,000.00
# 3     BMW    NaN        11179.0    5.0  $22,000.00
# 4  Nissan  White       213095.0    4.0   $3,500.00
# 5     NaN    NaN        99213.0    4.0   $4,500.00
# 6   Honda    NaN        45698.0    4.0   $7,500.00
# 7   Honda   Blue        54738.0    NaN         NaN
# 8  Toyota  White        60000.0    4.0   $6,250.00
# 9  Nissan  White        31600.0    NaN   $9,700.00

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# Fill the Odometer column missing values with the mean of the column inplace
missing_car_sales['Odometer (KM)'].fillna(missing_car_sales['Odometer (KM)'].mean(),inplace=True)

# %%
# View the car sales missing DataFrame and verify the changes
missing_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White   70663.444444    4.0   $4,000.00
# 1     NaN    Red   87899.000000    4.0         NaN
# 2  Toyota   Blue   32549.000000    3.0   $7,000.00
# 3     BMW    NaN   11179.000000    5.0  $22,000.00
# 4  Nissan  White  213095.000000    4.0   $3,500.00
# 5     NaN    NaN   99213.000000    4.0   $4,500.00
# 6   Honda    NaN   45698.000000    4.0   $7,500.00
# 7   Honda   Blue   54738.000000    NaN         NaN
# 8  Toyota  White   60000.000000    4.0   $6,250.00
# 9  Nissan  White   31600.000000    NaN   $9,700.00

# %%
# Remove the rest of the missing data inplace
missing_car_sales.dropna(inplace=True)

# %%
# Verify the missing values are removed by viewing the DataFrame
missing_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White   70663.444444    4.0  $4,000.00
# 2  Toyota   Blue   32549.000000    3.0  $7,000.00
# 4  Nissan  White  213095.000000    4.0  $3,500.00
# 8  Toyota  White   60000.000000    4.0  $6,250.00

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
missing_car_sales['Seats'] = 5
missing_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats
# 0  Toyota  White   70663.444444    4.0  $4,000.00      5
# 2  Toyota   Blue   32549.000000    3.0  $7,000.00      5
# 4  Nissan  White  213095.000000    4.0  $3,500.00      5
# 8  Toyota  White   60000.000000    4.0  $6,250.00      5

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
engine_sizes = [23.3,64.2,45.7,37.9]
missing_car_sales['Engine Sizes'] = engine_sizes
missing_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Engine Sizes
# 0  Toyota  White   70663.444444    4.0  $4,000.00      5          23.3
# 2  Toyota   Blue   32549.000000    3.0  $7,000.00      5          64.2
# 4  Nissan  White  213095.000000    4.0  $3,500.00      5          45.7
# 8  Toyota  White   60000.000000    4.0  $6,250.00      5          37.9

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
car_sales['Price/Kilometer'] = car_sales['Odometer (KM)']/car_sales['Price']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Price/Kilometer
# 0  toyota  White         150043      4   4000        37.510750
# 1   honda    Red          87899      4   5000        17.579800
# 2  toyota   Blue          32549      3   7000         4.649857
# 3     bmw  Black          11179      5  22000         0.508136
# 4  nissan  White         213095      4   3500        60.884286
# 5  toyota  Green          99213      4   4500        22.047333
# 6   honda   Blue          45698      4   7500         6.093067
# 7   honda   Blue          54738      4   7000         7.819714
# 8  toyota  White          60000      4   6250         9.600000
# 9  nissan  White          31600      4   9700         3.257732

# %%
# Remove the last column you added using .drop()
car_sales = car_sales.drop('Price/Kilometer',axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Price
# 0  toyota  White         150043   4000
# 1   honda    Red          87899   5000
# 2  toyota   Blue          32549   7000
# 3     bmw  Black          11179  22000
# 4  nissan  White         213095   3500
# 5  toyota  Green          99213   4500
# 6   honda   Blue          45698   7500
# 7   honda   Blue          54738   7000
# 8  toyota  White          60000   6250
# 9  nissan  White          31600   9700

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
car_sales_sampled = car_sales_sampled = car_sales.sample(frac=1)
car_sales_sampled
# Out:
#      Make Colour  Odometer (KM)  Price
# 0  toyota  White         150043   4000
# 3     bmw  Black          11179  22000
# 2  toyota   Blue          32549   7000
# 1   honda    Red          87899   5000
# 7   honda   Blue          54738   7000
# 5  toyota  Green          99213   4500
# 9  nissan  White          31600   9700
# 6   honda   Blue          45698   7500
# 4  nissan  White         213095   3500
# 8  toyota  White          60000   6250

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
car_sales_sampled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Price
# 0      0  toyota  White         150043   4000
# 1      3     bmw  Black          11179  22000
# 2      2  toyota   Blue          32549   7000
# 3      1   honda    Red          87899   5000
# 4      7   honda   Blue          54738   7000
# 5      5  toyota  Green          99213   4500
# 6      9  nissan  White          31600   9700
# 7      6   honda   Blue          45698   7500
# 8      4  nissan  White         213095   3500
# 9      8  toyota  White          60000   6250

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Price
# 0  toyota  White      93776.875   4000
# 1   honda    Red      54936.875   5000
# 2  toyota   Blue      20343.125   7000
# 3     bmw  Black       6986.875  22000
# 4  nissan  White     133184.375   3500
# 5  toyota  Green      62008.125   4500
# 6   honda   Blue      28561.250   7500
# 7   honda   Blue      34211.250   7000
# 8  toyota  White      37500.000   6250
# 9  nissan  White      19750.000   9700

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
car_sales = car_sales.rename(columns={"Odometer (KM)": "Odometer (Miles)"})
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Price
# 0  toyota  White         93776.875   4000
# 1   honda    Red         54936.875   5000
# 2  toyota   Blue         20343.125   7000
# 3     bmw  Black          6986.875  22000
# 4  nissan  White        133184.375   3500
# 5  toyota  Green         62008.125   4500
# 6   honda   Blue         28561.250   7500
# 7   honda   Blue         34211.250   7000
# 8  toyota  White         37500.000   6250
# 9  nissan  White         19750.000   9700
